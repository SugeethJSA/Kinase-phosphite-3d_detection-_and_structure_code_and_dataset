# %% [markdown]
# ## Stage 1: Siamese Neural Network Embedder
# In this section, we build and train a **Siamese Neural Network**. Its purpose is to learn a 100-dimensional mathematical representation (embedding) for kinase sequence motifs such that motifs belonging to the same kinase family are pushed closer together, while motifs from different families are pushed apart.

# %%
import time
import copy
import random
import numpy as np
import distance
import math
import pandas as pd
from collections import Counter

from sklearn.model_selection import train_test_split

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)
import torch.nn as nn
import torch
import torch.nn.functional as F
from torch import optim

from IPython.display import Audio

import numpy as np

train_motifs = np.genfromtxt(r'data/train_motifs.csv', dtype='U')
train_motifxFamMatrix = np.genfromtxt(r'data/train_motifxFamMatrix.csv', delimiter=',', dtype=int)
test_motifs = np.genfromtxt(r'data/new_test_motifs.csv', dtype='U')
test_motifxFamMatrix = np.genfromtxt(r'data/new_test_motifxFamMatrix.csv', delimiter=',', dtype=int)
fams = np.genfromtxt(r'data/fams.csv', dtype='U')


all_motifs = np.hstack([train_motifs,test_motifs])
all_motifxFamMatrix = np.vstack([train_motifxFamMatrix,test_motifxFamMatrix])

X_train, X_val = train_test_split(range(len(train_motifs)), test_size=0.1, random_state=666)

print(len(X_train), len(X_val), len(test_motifs))
# Out:
# 347 39 97

# %% [markdown]
# ### Helper Functions for Data Processing
# These functions are responsible for formatting the biological sequence motifs (like converting amino acids to one-hot or n-grams) and generating matched/mismatched batches for the Siamese network.

# %%
def get_gram_seq(motif,gram_length=1):
    gram_seq = []
    for i in range(len(motif)):
        gram = motif[i:i+gram_length]
        gram_seq.append(gram)
    return gram_seq

def get_encoded_motifs(grammed_motifs, all_grams):
    gram_counts = Counter(all_grams)
    gram_list = sorted(gram_counts, key=gram_counts.get, reverse=True)
    gram_to_int = {gram:idx+1 for idx, gram in enumerate(gram_list)}  
    encoded_motifs = [[gram_to_int[gram] for gram in motif] for motif in grammed_motifs]
    return encoded_motifs, gram_to_int, gram_list

AMINOS = 'XWGSAELQDMPFTRIHVNCY_K'
gram_length = 1  # Define the gram length

all_grams = []
train_grammed_motifs = []
for motif in train_motifs:
    grammed_motif = get_gram_seq(motif,gram_length)
    train_grammed_motifs.append(grammed_motif)
    all_grams.extend(grammed_motif)
    
test_grammed_motifs = []
for motif in test_motifs:
    grammed_motif = get_gram_seq(motif,gram_length)
    test_grammed_motifs.append(grammed_motif)
    all_grams.extend(grammed_motif)
    
vocab_size = len(set(all_grams))
print("vocab size:",vocab_size)

train_encoded_motifs, gram_to_int, gram_list = get_encoded_motifs(train_grammed_motifs, all_grams)
test_encoded_motifs, gram_to_int, gram_list = get_encoded_motifs(test_grammed_motifs, all_grams)
all_encoded_motifs = train_encoded_motifs + test_encoded_motifs
# Out:
# vocab size: 21

# %%
def get_random_motif_and_fam(idc):
    mIdx = random.choice(idc)  
    motif = train_encoded_motifs[mIdx] 
    fIdx = np.where(train_motifxFamMatrix[mIdx]==1)
    theseFams = fams[fIdx]
    return (mIdx,motif,fIdx,theseFams)

def get_batch(idc,batch_size):
    batch = []
    switch = 0
    
    while switch < batch_size:
        mIdx_1, motif_1, fIdx_1, fams_1 = get_random_motif_and_fam(idc)
        mIdx_2, motif_2, fIdx_2, fams_2 = get_random_motif_and_fam(idc)
        
        if len(fams_1)==0 and len(fams_2)==0: 
            continue
        
        label = distance.jaccard(set(fams_1),set(fams_2))
        if switch%2 != round(label):     # math.ceil(label):
            continue
        switch += 1
            
        triplet = [motif_1, motif_2, label]
        batch.append(triplet)

    return batch

# %%
def evaluate(model, idc, criterion, iters, batch_size, margin, dist_type):
    model.eval()
    loss_history = 0

    with torch.no_grad():
        
        for i in range(iters):
            batch = get_batch(idc, batch_size)
            motifs_net1 = torch.stack([torch.tensor(x[0]).to(device) for x in batch])
            motifs_net2 = torch.stack([torch.tensor(x[1]).to(device) for x in batch])
            labels = torch.stack([torch.tensor(x[2]).to(device) for x in batch])
            
            embeds_1, embeds_2 = model(motifs_net1, motifs_net2)
            loss = criterion(embeds_1, embeds_2, labels,margin, dist_type)
                
            loss_history += loss.item()
            
    return loss_history / iters

# %%
def train(model, idc, optimizer, criterion, iters, batch_size, margin, dist_type):
    model.train()
    loss_history = 0
    
    for i in range(iters):
            
        batch = get_batch(idc, batch_size)
        motifs_net1 = torch.stack([torch.tensor(x[0]).to(device) for x in batch])
        motifs_net2 = torch.stack([torch.tensor(x[1]).to(device) for x in batch])
        labels = torch.stack([torch.tensor(x[2]).to(device) for x in batch])
        
        optimizer.zero_grad()
        
        embeds_1, embeds_2 = model(motifs_net1, motifs_net2)
        loss = criterion(embeds_1, embeds_2, labels, margin, dist_type)
        
        loss.backward()
        optimizer.step()
                
        loss_history += loss.item()
        
    return loss_history / iters

# %% [markdown]
# ### Model Definitions: Siamese Architecture & Loss
# Here we define the custom distance loss function (Contrastive Loss) and the `Model` architecture itself, which uses PyTorch to process the sequence motifs.

# %%
class SiameseLoss(torch.nn.Module):
    def __init__(self):
        super().__init__()
        
    def forward(self, z1, z2, label, margin=2.0, dist_type='L2'):
        ''' Calculates the pairwise loss given two embeddings and their 0/1 label.
            margin: somewhere between 0.0 and 3.0
            dist_type: manhattan (L1) or euclidean (L2)
        '''
        if dist_type=='L2':
            distance = F.pairwise_distance(z1, z2)
        elif dist_type=='L1':
            distance = torch.sum( torch.abs(z1-z2), axis=1)
        siam_loss = torch.mean((1-label) * torch.pow(distance, 2) +
                                (label) * torch.pow(torch.clamp(margin - distance, min=0.0), 2))
        return siam_loss

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)
class Model(nn.Module):
            
    def __init__(self):
        super(Model, self).__init__()
        self.embedding = nn.Embedding(num_embeddings=vocab_size+1, embedding_dim=64)   
        
        self.lstm = nn.LSTM(64, 128, bidirectional=True,num_layers=2,
                            batch_first=True,dropout=0.2)
        
        self.fc1 = nn.Linear(128*2*15, 2048)
        self.fc2 = nn.Linear(2048, 1024)
        self.fc3 = nn.Linear(1024, 512)
        self.out = nn.Linear(512, 100)
        
        self.relu = nn.ReLU()
        self.drpt = nn.Dropout(p=0.0)
                
    def forward_once(self, motif): 
        
        embedded = self.embedding(motif)
        lstmed, _ = self.lstm(embedded)
        flattened = lstmed.reshape(lstmed.shape[0], lstmed.shape[1]*lstmed.shape[2])        
    
        fc1 = self.fc1(flattened)
        fc1 = self.relu(fc1)
        fc1 = self.drpt(fc1)
        
        fc2 = self.fc2(fc1)
        fc2 = self.relu(fc2)
        fc2 = self.drpt(fc2)
        
        fc3 = self.fc3(fc2)
        fc3 = self.relu(fc3)

        out = self.out(fc3)

        return out
        
    def forward(self, motifs_net1, motifs_net2):
        embed_1 = self.forward_once(motifs_net1)
        embed_2 = self.forward_once(motifs_net2)
        return (embed_1, embed_2)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = Model() 
model = model.to(device)

optimizer = optim.Adam(model.parameters(), lr = 0.005 ) 
criterion = SiameseLoss()

bs = 64

# A sub_iter is a single run through the network
sub_iters = 100
# Loss is calculated per super_iter (collection of sub_iters)
super_iters = 10

my_margin = 1.5
my_dist_type = 'L1'
print("Device:",device,"\n")

train_loss_history = []
val_loss_history = []
best_val_loss = float('inf')
total_time = time.time()

best_super = 0
for i in range(super_iters):
    start = time.time()
    train_loss = train(model, X_train, optimizer, criterion, 
                       iters=sub_iters, batch_size=bs, 
                       margin=my_margin, dist_type=my_dist_type)
    val_loss = evaluate(model, X_val, criterion, 
                        iters=sub_iters, batch_size=bs,
                        margin=my_margin, dist_type=my_dist_type)
    
    train_loss_history.append(train_loss)
    val_loss_history.append(val_loss)
    
    if val_loss <= best_val_loss:

        best_val_loss = val_loss
        best_model_wts = copy.deepcopy(model.state_dict())
        best_super = i

    print("Time: %5.3f secs, Super iter %d\n* Train loss %5.4f | Val loss: %5.4f" % 
          ( time.time()-start, i+1, train_loss, val_loss ))

final_model = Model().to(device)
final_model.load_state_dict(best_model_wts)
import os
import time
import torch 

# Ensure 'best_super' and 'total_time' are defined somewhere in the script
# Example values (replace these with actual values from your training loop)
best_super = 5  # Example: Last super iteration
total_time = time.time() - 1000  # Example: Replace with actual start time

# Print training details
print("--------------------\nLast super iter of learning:", best_super)
print("Total train time: %5.3f mins" % ((time.time() - total_time) / 60))



# Ensure the directory exists before saving the model
save_dir = "MODELS_siam/LEGACY"
os.makedirs(save_dir, exist_ok=True)

# Define a valid filename for the model
run = "latest"  # Change this to a timestamp, epoch number, etc., if needed
model_path = os.path.join(save_dir, f"siameseWeights_{run}.pth")

# Save model
torch.save(model.state_dict(), model_path)

print(f"Model saved to {model_path}")
# Out:
# Device: cuda
#
# Time: 3.985 secs, Super iter 1
# * Train loss 39.7760 | Val loss: 0.3463
# Time: 3.232 secs, Super iter 2
# * Train loss 0.2952 | Val loss: 0.3401
# Time: 3.149 secs, Super iter 3
# * Train loss 0.2800 | Val loss: 0.3214
# Time: 3.422 secs, Super iter 4
# * Train loss 0.2549 | Val loss: 0.3614
# Time: 3.515 secs, Super iter 5
# * Train loss 0.2336 | Val loss: 0.4217
# Time: 3.035 secs, Super iter 6
# * Train loss 0.2217 | Val loss: 0.3874
# Time: 2.942 secs, Super iter 7
# * Train loss 0.2147 | Val loss: 0.3908
# Time: 2.921 secs, Super iter 8
# * Train loss 0.1965 | Val loss: 0.4177
# Time: 2.838 secs, Super iter 9
# * Train loss 0.1868 | Val loss: 0.5427
# Time: 2.829 secs, Super iter 10
# * Train loss 0.1641 | Val loss: 0.5339
# --------------------
# Last super iter of learning: 5
# Total train time: 16.667 mins
# Model saved to MODELS_siam/LEGACY\siameseWeights_latest.pth

# %% [markdown]
# ### Extracting the Embeddings
# After the Siamese model is trained, this block converts all sequences into their dense 100-dimensional embeddings and saves them to a CSV file to be used by the multiclassifier later.

# %%
def get_embedding(model, enc_mots):
    model.eval()
    to_embed = torch.tensor(np.array((enc_mots))).to(device)
    embedding = model.forward_once(to_embed)
    return embedding.cpu().detach().numpy()

embedded = get_embedding(model,all_encoded_motifs)   #range(len(motifs)))
df = pd.DataFrame(embedded,dtype=float)
df.to_csv("MODELS_siam/LEGACY/emb_%s_embedding.csv" % (run),header=None,index=None)
# !pip install umap-learn

# %% [markdown]
# ### Visualization: UMAP Reduction
# To visually verify that the model has successfully separated the kinase families, we use UMAP to squash the 100-dimensional embeddings down to 2 dimensions so we can plot them on a scatter plot.

# %%
import umap.umap_ as umap
umapper = umap.UMAP(
    n_neighbors=20, # changed from 200
    min_dist=0.5, # changed from 0.1
    n_components=2,
    metric='euclidean' )

s = time.time()
pos_umap = umapper.fit_transform(embedded)
# allDone()

print ("secs: %5.3f" % (time.time()-s))
import os

# Make sure 'run' is defined
run = "latest"  # You can replace this with any desired name or string
f = os.path.join('FIGS_siam', 'LEGACY', run)  # Use os.path.join for platform-independent path construction

# Create the directory if it doesn't exist
os.makedirs(f, exist_ok=True)

label_size = 45
title_size = 50
tick_size = 40

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# secs: 0.580

# %%
plt.style.use('seaborn-v0_8-white')

colors = ['red','#CD0000','deepskyblue','blue','green','blueviolet','orange','magenta','blueviolet','violet','deeppink','crimson','mediumslateblue','brown']

plt.figure(figsize=(20, 20))
plt.scatter(pos_umap[:, 0], pos_umap[:, 1], marker='o', s=5, color='black', alpha=1)  # alpha=0.25
plt.title("Siamese latent space, UMAP reduction", fontsize=title_size, y=1.01)
plt.xlabel("UMAP-1", fontsize=label_size)
plt.ylabel("UMAP-2", fontsize=label_size)
plt.xticks(fontsize=tick_size)
plt.yticks(fontsize=tick_size)

plt.savefig(f + "/noHighlights")
plt.show()

pop_fams = ['PRKCA', 'AKT1', 'CDK1', 'MAPK1', 'SRC', 'ATM']
# pop_fams = ['CAMK-UNIQUE', 'DYRK', 'CAMKL', 'STE20', 'PKC', 'AKT', 'CDK', 'MAPK', 'SRC', 'CK2', 'PKA', 'PIKK']

i = -1
for _, fam in enumerate(pop_fams):
    i += 1
    fIdx = np.where(fams == fam)[0][0]
    plt.figure(figsize=(20, 20))
    plt.title(f"Siamese latent space, UMAP reduction: {fam}", fontsize=title_size, y=1.01)
    plt.xticks(fontsize=tick_size)
    plt.yticks(fontsize=tick_size)
    plt.xlabel("UMAP-1", fontsize=label_size)
    plt.ylabel("UMAP-2", fontsize=label_size)
    
    plt.scatter(pos_umap[:, 0], pos_umap[:, 1], marker='o', s=25, color='grey', alpha=0.30)
    
    for mIdx, (x, y) in enumerate(zip(pos_umap[:, 0], pos_umap[:, 1])):
        if all_motifs[mIdx] not in test_motifs:
            continue
        elif all_motifxFamMatrix[mIdx][fIdx] == 1:
            plt.scatter(x, y, marker='o', s=200, c=colors[i], alpha=1.0, edgecolors='black')
    
    plt.savefig(f + f"/{fam}")
    plt.show()
import os
import shutil

# Define the directory
run = "latest"
output_dir = os.path.join('FIGS_siam', 'LEGACY', run)

# Create a ZIP file
zip_file = output_dir + ".zip"
shutil.make_archive(output_dir, 'zip', output_dir)

# Confirm the zip file is created
print(f"Download your images: {zip_file}")
# Out:
# Download your images: FIGS_siam\LEGACY\latest.zip

# %% [markdown]
# ## Stage 2: Multiclassifier Training
# Now that we have rich 100D embeddings for our motifs, we can train a final dense neural network (the Multiclassifier) to predict the exact kinase family. This section sets up the data loaders and 5-Fold Cross Validation logic.

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)
import os
import time
import copy
import random
import numpy as np
import math

from sklearn.metrics import roc_curve, auc
from IPython.display import Audio

import torch
import torch.nn as nn
import torch.utils.data as data_utils

from multiclassifier import Model

seedy = 666
random.seed(seedy)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def allDone():
    print("Training Complete!")
train_motifs = np.genfromtxt(r'data/train_motifs.csv', dtype='U')
train_motifxFamMatrix = np.genfromtxt(r'data/train_motifxFamMatrix.csv', delimiter=',', dtype=int)
test_motifs = np.genfromtxt(r'data/new_test_motifs.csv', dtype='U')
test_motifxFamMatrix = np.genfromtxt(r'data/new_test_motifxFamMatrix.csv', delimiter=',', dtype=int)
fams = np.genfromtxt(r'data/fams.csv', dtype='U')


## Split data into folds in a stratified k-fold manner.

# %%
def proba_mass_split(y, folds=5):
    obs, classes = y.shape
    dist = y.sum(axis=0).astype('float')
    dist /= dist.sum()
    index_list = []
    fold_dist = np.zeros((folds, classes), dtype='float')
    for _ in range(folds):
        index_list.append([])
    for i in range(obs):
        if i < folds:
            target_fold = i
        else:
            normed_folds = fold_dist.T / fold_dist.sum(axis=1)
            how_off = normed_folds.T - dist
            target_fold = np.argmin(np.dot((y[i] - .5).reshape(1, -1), how_off.T))
        fold_dist[target_fold] += y[i]
        index_list[target_fold].append(i)
    return index_list

np.random.seed(seedy)
folds = proba_mass_split(train_motifxFamMatrix)
#############################################
# Get Siamese embedding coords.
#############################################

embedding = np.genfromtxt(r"MODELS_siam/LEGACY/emb_latest_embedding.csv",delimiter=',',dtype=float)
train_embedding = embedding[ :len(train_motifs) ]
test_embedding = embedding[ len(train_motifs): ]
print(embedding.shape)

#############################################
# Get fam distance matrix for Phylo MSE loss.
#############################################

all_fams = (np.genfromtxt(r"data\fam_distances_blos62\fams.csv",dtype='U'))
dist_matrix = (np.genfromtxt(r"data\fam_distances_blos62\dist_matrix.csv",delimiter=',',dtype=float))

fam_idc = [np.where(all_fams==fam)[0][0] for fam in fams]
fam_dist_matrix = dist_matrix[fam_idc][:,fam_idc]
        
# normalize fam distances
fMax = np.max(fam_dist_matrix)
fMin = np.min(fam_dist_matrix)

fam_dist_matrix_scaled = np.array((fam_dist_matrix))
for i in range(len(fams)):
    for j in range(len(fams)):
        fam_dist_matrix_scaled[i][j] = 1 - float(fam_dist_matrix[i][j]-fMin)/(fMax-fMin) 
fam_dist_matrix = fam_dist_matrix_scaled

famDistMatrix = fam_dist_matrix
AMINOS = 'XWGSAELQDMPFTRIHVNCY_K'
# Out:
# (483, 100)

# %%
def get_oneHot_motifs(motifs, AMINOS=AMINOS):
    oneHot_motifs = []
    for motif in motifs:
        one_hotted = np.zeros((len(motif), len(AMINOS)),dtype=float)
        for i,aa in enumerate(motif):
            hot = AMINOS.find(aa)
            one_hotted[i][hot] = 1
        oneHot_motifs.append(one_hotted)
    oneHot_motifs = np.asarray(oneHot_motifs)
    oneHot_motifs = np.swapaxes(oneHot_motifs,1,2)
    return oneHot_motifs

# %%
def get_stacked_features(motifs, embeddings):
    oneHot_motifs = get_oneHot_motifs(motifs)
    squished_oneHots = oneHot_motifs.reshape(oneHot_motifs.shape[0],oneHot_motifs.shape[1]*
                                         oneHot_motifs.shape[2])
    stacked_features = np.hstack((squished_oneHots,embeddings))
    stacked_features = torch.tensor(stacked_features)
    return stacked_features        


def get_loader(motifs,embedding,motifxFamMatrix,idc,my_batch):
    these_motifs = motifs[idc]
    this_embedding = embedding[idc]
    X = get_stacked_features(these_motifs,this_embedding)
    Y = torch.tensor(motifxFamMatrix[idc])
    dataset = data_utils.TensorDataset(X, Y)
    loader = data_utils.DataLoader(dataset, batch_size=my_batch, shuffle=True, drop_last=True)
    return loader

# %%
def get_microROC(y_test, y_score):
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    
    for i in range(len(fams)):
        fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    fpr_micro, tpr_micro, _ = roc_curve(y_test.ravel(), y_score.ravel())
    return auc(fpr_micro, tpr_micro)

# %% [markdown]
# ### Multiclassifier Training Loop
# This function handles the actual PyTorch training loop for the dense multiclassifier, including computing BCE loss, accuracy, and handling backpropagation.

# %%
def train_model(train_loader, val_loader, model, optimizer, batch_size, num_epochs, stopper='loss', 
                version='seq-coord', this_loss='phylo'):
    
    train_losses = []
    train_accs = []
    val_losses = []
    val_accs = []
    
    running = - math.inf
    current = running
    best_run = 0
    best_model = copy.deepcopy(model.state_dict())
    
    for epoch in range(num_epochs):
        
        print("Epoch",epoch+1)
        for phase in ['train','validate']:
            running_loss = 0.0
            running_acc = 0.0
            if phase=='train':
                loader = train_loader
                model.train()
            else:
                loader = val_loader
                model.eval()
                
            for inputs,labels in loader:
                inputs = inputs.float().to(device)
                labels = labels.float().to(device)
                motif = inputs[:,:-embedding.shape[1]].reshape( batch_size, len(AMINOS), len(train_motifs[0]) )
                coords = inputs[:,-embedding.shape[1]:]

                optimizer.zero_grad()
                with torch.set_grad_enabled(phase=='train'):
                    outputs = model.forward(motif, coords, version)
                    if this_loss=='phylo':
                        loss = phylo_error(outputs,labels)
                    elif this_loss!='phylo':
                        criterion = nn.BCELoss() # BCE loss is the usual loss to use.
                        loss = criterion(outputs, labels)
                    if phase=='train':
                        loss.backward()
                        optimizer.step()
                running_loss += loss.item()

                y_test = np.asarray(labels.cpu())
                y_score = outputs.cpu().detach().numpy()
                acc = get_microROC(y_test, y_score)
                running_acc += acc
            
            loss = running_loss / len(loader) 
            acc =  running_acc / len(loader) 
            
            if phase=='train':
                train_losses.append(loss)
                train_accs.append(acc)
                
            elif phase=='validate':
                val_losses.append(loss)
                val_accs.append(acc)
                
                if stopper=='loss':
                    current = -loss
                elif stopper=='acc':
                    current = acc
                elif stopper=='epoch':
                    current = epoch
                if current >= running:
                    running = current
                    best_run = epoch+1
                    best_model = copy.deepcopy(model.state_dict()) 
                
            print("~ %s LOSS: %5.3f | ACC: %5.3f" % (phase,loss,acc))
            if current >= running and phase=='validate':
                print("      BEST SO FAR ^ ^ ^")
        
    return (best_run, best_model, train_losses, train_accs, val_losses, val_accs)

# %%
def phylo_error(output, target):
        
    weights = np.ones((output.shape[0],output.shape[1]))

    for i,t in enumerate(target):
        t = t.cpu()
        wIdc = np.where(t.detach().numpy()==1)[0]

        if len(wIdc)==0:
            weights[i] = 0.000001
            continue
        theseWeights = np.ones((len(fams)))
        
        for wIdx in wIdc:
            thisWeight = famDistMatrix[wIdx].copy() # inter-fam
            thisWeight[wIdx] =  1.00 - famDistMatrix[wIdx][wIdx].copy() # intra-fam
            theseWeights+=thisWeight # add to existing list of fam distances, respectively (element wise)
            
        fWeight = theseWeights/len(fams) # take median / average
        weights[i] = fWeight 
        
    weights = torch.tensor(weights)
    weights = weights.to(device)
    crit = nn.BCELoss(reduction=my_reduction)
    answer = crit(output, target) * weights.mean().float()

    return answer
# # # # # # # # # # # # # # # # # # # # # # # # # # #
my_version = 'seq-coord'        
my_loss = 'phylo'            

my_stopper = 'loss'
my_batch = 32
my_epochs = 40
my_lr = 0.0015

my_reduction = 'sum'
# # # # # # # # # # # # # # # # # # # # # # # # # # #
s = time.time()

all_train_losses = []
all_train_accs = []
all_val_losses = []
all_val_accs = []

all_best_runs = []
all_models = []

for i,fold in enumerate(folds):
    
    print("\n* * * * * * * * FOLD %d * * * * * * * *\n" %(i+1))
    
    fold_val_idc = fold
    fold_train_idc = [x for x in range(len(train_motifs)) if x not in fold_val_idc]
    
    train_loader = get_loader(train_motifs,train_embedding,train_motifxFamMatrix,fold_train_idc,my_batch)
    val_loader = get_loader(train_motifs,train_embedding,train_motifxFamMatrix,fold_val_idc,my_batch)
    
    model = Model()
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(),lr = my_lr)
    
    (best_run, best_model, train_losses, train_accs, val_losses, val_accs) = \
                    train_model(train_loader, val_loader,
                                model, optimizer,my_batch, 
                                my_epochs,my_stopper,my_version,
                                my_loss)
    
    all_best_runs.append(best_run)
    all_models.append(best_model)
    all_train_losses.append(train_losses)
    all_train_accs.append(train_accs)
    all_val_losses.append(val_losses)
    all_val_accs.append(val_accs)
    
print("TIME: %5.3f mins" % ((time.time()-s)/60))
print("BEST RUNS:",all_best_runs)

allDone()
run = 'experiment_1'  # Example valid name for the directory

# Check if the directory exists, if not, create it
if not os.path.exists("MODELS_multiclass/%s/" % run):
    os.makedirs("MODELS_multiclass/%s/" % run)

# Iterate over all models and save their weights
for i, model_weights in enumerate(all_models):
    torch.save(model_weights, "MODELS_multiclass/%s/%d_weights" % (run, i))
all_train_losses_arr = np.zeros(my_epochs)
all_train_accs_arr = np.zeros(my_epochs)
all_val_losses_arr = np.zeros(my_epochs)
all_val_accs_arr = np.zeros(my_epochs)

for i in range(my_epochs):
    all_train_losses_arr[i] = sum([all_train_losses[j][i] for j in range(len(folds))]) / len(folds)
    all_train_accs_arr[i] = sum([all_train_accs[j][i] for j in range(len(folds))]) / len(folds)
    all_val_losses_arr[i] = sum([all_val_losses[j][i] for j in range(len(folds))]) / len(folds)
    all_val_accs_arr[i] = sum([all_val_accs[j][i] for j in range(len(folds))]) / len(folds)
    
if my_reduction=='sum':
    all_train_losses_arr=all_train_losses_arr*.005
    all_val_losses_arr=all_val_losses_arr*.005
    
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ~ validate LOSS: 5.886 | ACC: 0.757
# Epoch 30
# ~ train LOSS: 0.732 | ACC: 0.999
# ~ validate LOSS: 4.743 | ACC: 0.869
# Epoch 31
# ~ train LOSS: 0.706 | ACC: 0.999
# ~ validate LOSS: 5.612 | ACC: 0.813
# Epoch 32
# ~ train LOSS: 0.639 | ACC: 0.999
# ~ validate LOSS: 6.648 | ACC: 0.748
# Epoch 33
# ~ train LOSS: 0.604 | ACC: 1.000
# ~ validate LOSS: 5.606 | ACC: 0.842
# Epoch 34
# ~ train LOSS: 0.508 | ACC: 1.000
# ~ validate LOSS: 6.566 | ACC: 0.780
# Epoch 35
# ~ train LOSS: 0.468 | ACC: 1.000
# ~ validate LOSS: 6.209 | ACC: 0.810
# Epoch 36
# ~ train LOSS: 0.469 | ACC: 1.000
# ~ validate LOSS: 6.486 | ACC: 0.810
# Epoch 37
# ~ train LOSS: 0.362 | ACC: 1.000
# ~ validate LOSS: 6.367 | ACC: 0.819
# Epoch 38
# ~ train LOSS: 0.359 | ACC: 1.000
# ~ validate LOSS: 5.735 | ACC: 0.848
# Epoch 39
# ~ train LOSS: 0.319 | ACC: 1.000
# ~ validate LOSS: 7.893 | ACC: 0.737
# Epoch 40
# ~ train LOSS: 0.313 | ACC: 1.000
# ~ validate LOSS: 7.566 | ACC: 0.780
# TIME: 0.775 mins
# BEST RUNS: [10, 12, 14, 10, 11]
# Training Complete!

# %% [markdown]
# ### Execution & ROC Plotting
# This cell executes the K-fold cross validation pipeline, tests the model, and generates an ROC curve mapping True Positive vs False Positive rates.

# %%
plt.figure(figsize=(7.5,5))

plt.plot(all_train_losses_arr,label='Train loss',c='blue')
plt.plot(all_val_losses_arr,label='Val loss',c='green')
plt.plot(all_train_accs_arr,label='Train acc',c='red')
plt.plot(all_val_accs_arr,label='Val acc',c='orange')

plt.xlabel("Epoch")
plt.legend(loc='center right')
import os
os.makedirs("FIGS_multiclass", exist_ok=True)
plt.savefig("FIGS_multiclass/" + run + "_loss-acc")

plt.show()

# %% [markdown]
# ## Stage 3: Evaluation
# This final block takes the trained model and tests it on completely unseen `test_motifs`. It generates confusion matrices and final metric scores so you can see exactly where the model succeeded and where it got confused.

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)
import random
import numpy as np
import math

import torch
import torch.utils.data as data_utils

import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score

from multiclassifier import Model

seedy = 666
random.seed(seedy)
train_motifs = np.genfromtxt(r'data/train_motifs.csv', dtype='U')
train_motifxFamMatrix = np.genfromtxt(r'data/train_motifxFamMatrix.csv', delimiter=',', dtype=int)
test_motifs = np.genfromtxt(r'data/new_test_motifs.csv', dtype='U')
test_motifxFamMatrix = np.genfromtxt(r'data/new_test_motifxFamMatrix.csv', delimiter=',', dtype=int)
fams = np.genfromtxt(r'data/fams.csv', dtype='U')

## Split data into folds in a stratified k-fold manner.

# %%
def proba_mass_split(y, folds=5):
    obs, classes = y.shape
    dist = y.sum(axis=0).astype('float')
    dist /= dist.sum()
    index_list = []
    fold_dist = np.zeros((folds, classes), dtype='float')
    for _ in range(folds):
        index_list.append([])
    for i in range(obs):
        if i < folds:
            target_fold = i
        else:
            normed_folds = fold_dist.T / fold_dist.sum(axis=1)
            how_off = normed_folds.T - dist
            target_fold = np.argmin(np.dot((y[i] - .5).reshape(1, -1), how_off.T))
        fold_dist[target_fold] += y[i]
        index_list[target_fold].append(i)
    return index_list

np.random.seed(seedy)
folds = proba_mass_split(train_motifxFamMatrix)
#############################################
# Get Siamese embedding coords.
#############################################

embedding = np.genfromtxt(r"MODELS_siam/LEGACY/emb_latest_embedding.csv",delimiter=',',dtype=float)
train_embedding = embedding[ :len(train_motifs) ]
test_embedding = embedding[ len(train_motifs): ]
print(embedding.shape)

#############################################
# Get fam distance matrix for Phylo MSE loss.
#############################################

all_fams = (np.genfromtxt(r"data\fam_distances_blos62\fams.csv",dtype='U'))
dist_matrix = (np.genfromtxt(r"data\fam_distances_blos62\dist_matrix.csv",delimiter=',',dtype=float))

fam_idc = [np.where(all_fams==fam)[0][0] for fam in fams]
fam_dist_matrix = dist_matrix[fam_idc][:,fam_idc]
        
# normalize fam distances
fMax = np.max(fam_dist_matrix)
fMin = np.min(fam_dist_matrix)

fam_dist_matrix_scaled = np.array((fam_dist_matrix))
for i in range(len(fams)):
    for j in range(len(fams)):
        fam_dist_matrix_scaled[i][j] = 1 - float(fam_dist_matrix[i][j]-fMin)/(fMax-fMin) 
fam_dist_matrix = fam_dist_matrix_scaled

famDistMatrix = fam_dist_matrix
AMINOS = 'XWGSAELQDMPFTRIHVNCY_K'
# Out:
# (483, 100)

# %%
def get_oneHot_motifs(motifs, AMINOS=AMINOS):
    oneHot_motifs = []
    for motif in motifs:
        one_hotted = np.zeros((len(motif), len(AMINOS)),dtype=float)
        for i,aa in enumerate(motif):
            hot = AMINOS.find(aa)
            one_hotted[i][hot] = 1
        oneHot_motifs.append(one_hotted)
    oneHot_motifs = np.asarray(oneHot_motifs)
    oneHot_motifs = np.swapaxes(oneHot_motifs,1,2)
    return oneHot_motifs

# %%
def get_stacked_features(motifs, embeddings):
    oneHot_motifs = get_oneHot_motifs(motifs)
    squished_oneHots = oneHot_motifs.reshape(oneHot_motifs.shape[0],oneHot_motifs.shape[1]*
                                         oneHot_motifs.shape[2])
    stacked_features = np.hstack((squished_oneHots,embeddings))
    stacked_features = torch.tensor(stacked_features)
    return stacked_features        

def get_loader(motifs,embedding,motifxFamMatrix,idc,my_batch):
    these_motifs = motifs[idc]
    this_embedding = embedding[idc]
    X = get_stacked_features(these_motifs,this_embedding)
    Y = torch.tensor(motifxFamMatrix[idc])
    dataset = data_utils.TensorDataset(X, Y)
    loader = data_utils.DataLoader(dataset, batch_size=my_batch, shuffle=True, drop_last=True)
    return loader

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)
def eval_model(model, thresh=0.5):
    
    model.eval()
    loader = get_loader(test_motifs,test_embedding,test_motifxFamMatrix,range(len(test_motifs)),len(test_motifs))
    
    for inputs, labels in loader:
        
        inputs = inputs.float().to(device)
        labels = labels.float().to(device)

        motif = inputs[:,:-embedding.shape[1]].reshape( len(test_motifs), len(AMINOS), len(train_motifs[0]) )
        coords = inputs[:,-embedding.shape[1]:]
        
        outputs = model.forward(motif, coords)
        
        accuracy = 0
        totTrues = 0
        for i,out in enumerate(outputs):
            pred = np.where(out.cpu().detach().numpy() > thresh)[0]
            true = np.where(labels.data.cpu()[i]==1)[0]
            totTrues += len(true)
            accuracy += len(pred)

        y_score = outputs.cpu().detach().numpy()
        y_test = np.asarray(labels.cpu())
                
        return y_test, y_score
import torch
import numpy as np

# Ensure the device is set correctly
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Set the run variable
run = '00'

# Initialize lists to store the scores and test labels
all_y_scores = []
all_y_test = []

# Loop through the models and evaluate them
for i in range(5):
    # Initialize the model and move it to the appropriate device
    model = Model()
    model = model.to(device)
    
    # Load the saved model weights explicitly to the CPU if necessary
    model.load_state_dict(torch.load(f"MODELS_multiclass/experiment_1/{i}_weights", map_location=device))
    
    # Evaluate the model and extend the results into the lists
    y_test, y_score = eval_model(model)
    all_y_scores.extend(y_score)
    all_y_test.extend(y_test)

# Convert the results to numpy arrays
y_score = np.asarray(all_y_scores)
y_test = np.asarray(all_y_test)

## ROC



FAM_IDC = [x for x in range(len(fams))]

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in FAM_IDC:
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_score[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_score.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in FAM_IDC]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in FAM_IDC:
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= len(FAM_IDC)

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
## PRECISION-RECALL



precision = dict()
recall = dict()
average_precision = dict()

for i in range(len(fams)):
    precision[i], recall[i], _ = precision_recall_curve(y_test[:, i], y_score[:, i])
    average_precision[i] = average_precision_score(y_test[:, i], y_score[:, i])

precision["micro"], recall["micro"], _ = precision_recall_curve(y_test.ravel(), y_score.ravel())

average_precision["micro"] = average_precision_score(y_test, y_score, average="micro")
average_precision["macro"] = average_precision_score(y_test, y_score, average="macro")
import matplotlib.pyplot as plt
cmap = plt.get_cmap("tab20")
fam_to_col = {fam: cmap(idx % 20) for idx, fam in enumerate(fams)}
# from itertools import cycle

plt.style.use('default')
# fig, (ax1, ax2) = plt.subplots(2,figsize=(5,11))
fig, (ax1, ax2) = plt.subplots(1,2,figsize=(11,5))

lw = 1.25

############################################################
###################  AUROC #################################
############################################################

lines = []
labels = []

l, = ax1.plot(0,0,color='white')
lines.append(l)
labels.append('micro-average (area = {0:0.3f})'.format(roc_auc["micro"]))
l, = ax1.plot(0,0,color='white')
lines.append(l)
labels.append('macro-average (area = {0:0.3f})'.format(roc_auc["macro"]))

for i,fam in enumerate(fams):
    fclass = fams[i]
    if fclass=='AKT':
        fclass = 'Akt'
    if fclass=='SRC':
        fclass = 'Src'    
    l, = ax1.plot(fpr[i], tpr[i], color=fam_to_col[fam], lw=lw,
             label='{0} (area = {1:0.3f})'.format(fclass, roc_auc[i]))
    labels.append('{0} (area = {1:0.3f})'.format(fclass, roc_auc[i]))
    lines.append(l)

fig.subplots_adjust(hspace=.275)
ax1.plot([0, 1], [0, 1], 'k--', lw=lw)
ax1.set_xlim([0.0, 1.0])
ax1.set_ylim([0.0, 1.05])
ax1.tick_params(axis="x", labelsize=10)
ax1.tick_params(axis="y", labelsize=10)
ax1.set_xlabel('False Positive Rate',fontsize=12)
ax1.set_ylabel('True Positive Rate',fontsize=12) 
ax1.set_title('ROC curve per kinase family',fontsize=12) 
labels, lines = zip(*sorted(zip(labels, lines), key=lambda t: t[0], reverse=False))
ax1.legend(lines, labels, loc=(0.475, .0175), fontsize=7.5)  # (1.05, .0)

############################################################
###############  PRECISION-RECALL ##########################
############################################################

lines = []
labels = []

l, = ax2.plot(0,0,color='white')
lines.append(l)
labels.append('micro-average (area = {0:0.3f})'.format(average_precision["micro"]))
l, = ax2.plot(0,0,color='white')
lines.append(l)
labels.append('macro-average (area = {0:0.3f})'.format(average_precision["macro"]))

for i,fam in enumerate(fams):
    l, = ax2.plot(recall[i], precision[i], color=fam_to_col[fam], lw=lw)
    lines.append(l)
    fclass = fams[i]
    if fclass=='AKT':
        fclass = 'Akt'
    if fclass=='SRC':
        fclass = 'Src'
    labels.append('{0} (area = {1:0.3f})'.format(fclass, average_precision[i]))

ax2.set_xlim([0.0, 1.0])
ax2.set_ylim([0.0, 1.05])
ax2.tick_params(axis="x", labelsize=10)
ax2.tick_params(axis="y", labelsize=10)
ax2.set_xlabel('Recall',fontsize=12) 
ax2.set_ylabel('Precision',fontsize=12) 
ax2.set_title('Precision-recall curve per kinase family',fontsize=12) 

labels, lines = zip(*sorted(zip(labels, lines), key=lambda t: t[0], reverse=False))
ax2.legend(lines, labels, loc=(0.025, .0175), fontsize=7.5) # (1.05, .0)

import os
os.makedirs("FIGS_multiclass", exist_ok=True)
plt.savefig("FIGS_multiclass/%s_roc-prc" % run, bbox_inches='tight')
plt.show()
confusion = np.zeros((len(fams), len(fams)),dtype=float)

for i,score in enumerate(y_score):
    pred = np.where(score > 0.5000)[0]
    if len(pred)<1:
        pred = [np.argmax(score)]
    true = np.where(y_test[i]==1)[0]
    for p_idx in pred:
        for t_idx in true:
            confusion[p_idx][t_idx] += 1
            
labs = confusion.copy()

for i in range(len(fams)):
    confusion[i] = confusion[i] / confusion[i].sum()
for i in range(len(fams)):
    for j in range(len(fams)):
        if math.isnan(confusion[i][j]) or confusion[i][j]==0:
            confusion[i][j]=0
heat_map = sb.heatmap(confusion, annot=labs, cmap="GnBu_r", fmt='1.0f',
                      square=False, yticklabels=fams, xticklabels=fams )

b, t = plt.ylim() 
plt.ylim(b, t) 

plt.xlabel("True label",fontsize=12, labelpad=10)
plt.ylabel("Predicted label",fontsize=12, labelpad=10)
plt.title("Confusion matrix for kinase labels",fontsize=12, pad=12)
import os
os.makedirs("FIGS_multiclass", exist_ok=True)
plt.savefig("FIGS_multiclass/%s_confusion" % run, bbox_inches='tight')

plt.show()

# %%
# Install libraries for advanced visualizations
# !pip install shap lifelines
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: shap in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.52.0)
# Requirement already satisfied: lifelines in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.30.3)
# Requirement already satisfied: numpy>=2 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (2.3.4)
# Requirement already satisfied: scipy in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (1.17.1)
# Requirement already satisfied: scikit-learn in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (1.8.0)
# Requirement already satisfied: pandas in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (2.3.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (4.67.3)
# Requirement already satisfied: packaging>20.9 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (26.0)
# Requirement already satisfied: slicer==0.0.8 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (0.65.1)
# Requirement already satisfied: llvmlite in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (0.47.0)
# Requirement already satisfied: cloudpickle in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from shap) (3.1.2)
# Requirement already satisfied: matplotlib>=3.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from lifelines) (3.10.8)
# Requirement already satisfied: autograd>=1.5 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from lifelines) (1.8.0)
# Requirement already satisfied: autograd-gamma>=0.3 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from lifelines) (0.5.0)
# Requirement already satisfied: formulaic>=0.2.2 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from lifelines) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: interface-meta>=1.2.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from formulaic>=0.2.2->lifelines) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from formulaic>=0.2.2->lifelines) (2.22.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from formulaic>=0.2.2->lifelines) (4.15.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from formulaic>=0.2.2->lifelines) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.0->lifelines) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.0->lifelines) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.0->lifelines) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.0->lifelines) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.0->lifelines) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.0->lifelines) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: colorama in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn->shap) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\inaug\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from scikit-learn->shap) (3.6.0)
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: C:\Users\inaug\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.filterwarnings('ignore', category=UndefinedMetricWarning)
warnings.filterwarnings('ignore', category=UserWarning)
# ----------------------------------------------------------------------
# Section: Model Variant Training & Performance Metrics Harvesting
# ----------------------------------------------------------------------
import copy
import numpy as np
import torch
import torch.nn as nn
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
from multiclassifier import Model

# We will collect accuracy, precision, recall, and f1 scores for each variant
metrics_harvest = {
    'Combined (Seq+Coord)': {'Accuracy': [], 'Precision-Macro': [], 'Precision-Micro': [], 'Recall-Macro': [], 'Recall-Micro': [], 'F1-Macro': [], 'F1-Micro': [], 'AUC-Micro': []},
    'Sequence-Only': {'Accuracy': [], 'Precision-Macro': [], 'Precision-Micro': [], 'Recall-Macro': [], 'Recall-Micro': [], 'F1-Macro': [], 'F1-Micro': [], 'AUC-Micro': []},
    'Coordinate-Only': {'Accuracy': [], 'Precision-Macro': [], 'Precision-Micro': [], 'Recall-Macro': [], 'Recall-Micro': [], 'F1-Macro': [], 'F1-Micro': [], 'AUC-Micro': []}
}

# 1. Harvest metrics for Combined model using saved fold weights
print("Harvesting metrics for Combined model...")
for i, fold in enumerate(folds):
    fold_val_idc = fold
    val_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_val_idc, len(fold_val_idc))
    
    # Load model
    model = Model().to(device)
    model.load_state_dict(all_models[i])
    model.eval()
    
    for inputs, labels in val_loader:
        inputs = inputs.float().to(device)
        labels = labels.float().to(device)
        motif = inputs[:,:-embedding.shape[1]].reshape(len(fold_val_idc), len(AMINOS), len(train_motifs[0]))
        coords = inputs[:,-embedding.shape[1]:]
        
        with torch.no_grad():
            outputs = model(motif, coords, version='seq-coord')
            
        y_test = labels.cpu().numpy()
        y_score = outputs.cpu().numpy()
        y_pred = np.zeros_like(y_score)
        for r_idx, score in enumerate(y_score):
            y_pred[r_idx, np.argmax(score)] = 1
        
        metrics_harvest['Combined (Seq+Coord)']['Accuracy'].append(accuracy_score(y_test, y_pred))
        metrics_harvest['Combined (Seq+Coord)']['Precision-Macro'].append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Combined (Seq+Coord)']['Precision-Micro'].append(precision_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Combined (Seq+Coord)']['Recall-Macro'].append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Combined (Seq+Coord)']['Recall-Micro'].append(recall_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Combined (Seq+Coord)']['F1-Macro'].append(f1_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Combined (Seq+Coord)']['F1-Micro'].append(f1_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Combined (Seq+Coord)']['AUC-Micro'].append(get_microROC(y_test, y_score))

# 2. Train and evaluate Sequence-Only model
print("\nTraining and harvesting Sequence-Only models...")
all_seq_models = []
for i, fold in enumerate(folds):
    print(f"--- FOLD {i+1} (Seq-Only) ---")
    fold_val_idc = fold
    fold_train_idc = [x for x in range(len(train_motifs)) if x not in fold_val_idc]
    
    train_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_train_idc, my_batch)
    val_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_val_idc, my_batch)
    
    model = Model().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=my_lr)
    
    (best_run, best_model, _, _, _, _) = train_model(
        train_loader, val_loader, model, optimizer, my_batch, 
        num_epochs=my_epochs, stopper=my_stopper, version='seq-only', this_loss=my_loss
    )
    all_seq_models.append(best_model)
    
    # Evaluate
    val_eval_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_val_idc, len(fold_val_idc))
    model.load_state_dict(best_model)
    model.eval()
    
    for inputs, labels in val_eval_loader:
        inputs = inputs.float().to(device)
        labels = labels.float().to(device)
        motif = inputs[:,:-embedding.shape[1]].reshape(len(fold_val_idc), len(AMINOS), len(train_motifs[0]))
        coords = inputs[:,-embedding.shape[1]:]
        
        with torch.no_grad():
            outputs = model(motif, coords, version='seq-only')
            
        y_test = labels.cpu().numpy()
        y_score = outputs.cpu().numpy()
        y_pred = np.zeros_like(y_score)
        for r_idx, score in enumerate(y_score):
            y_pred[r_idx, np.argmax(score)] = 1
        
        metrics_harvest['Sequence-Only']['Accuracy'].append(accuracy_score(y_test, y_pred))
        metrics_harvest['Sequence-Only']['Precision-Macro'].append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Sequence-Only']['Precision-Micro'].append(precision_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Sequence-Only']['Recall-Macro'].append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Sequence-Only']['Recall-Micro'].append(recall_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Sequence-Only']['F1-Macro'].append(f1_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Sequence-Only']['F1-Micro'].append(f1_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Sequence-Only']['AUC-Micro'].append(get_microROC(y_test, y_score))

# 3. Train and evaluate Coordinate-Only model
print("\nTraining and harvesting Coordinate-Only models...")
all_coord_models = []
for i, fold in enumerate(folds):
    print(f"--- FOLD {i+1} (Coord-Only) ---")
    fold_val_idc = fold
    fold_train_idc = [x for x in range(len(train_motifs)) if x not in fold_val_idc]
    
    train_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_train_idc, my_batch)
    val_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_val_idc, my_batch)
    
    model = Model().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=my_lr)
    
    (best_run, best_model, _, _, _, _) = train_model(
        train_loader, val_loader, model, optimizer, my_batch, 
        num_epochs=my_epochs, stopper=my_stopper, version='coord-only', this_loss=my_loss
    )
    all_coord_models.append(best_model)
    
    # Evaluate
    val_eval_loader = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, fold_val_idc, len(fold_val_idc))
    model.load_state_dict(best_model)
    model.eval()
    
    for inputs, labels in val_eval_loader:
        inputs = inputs.float().to(device)
        labels = labels.float().to(device)
        motif = inputs[:,:-embedding.shape[1]].reshape(len(fold_val_idc), len(AMINOS), len(train_motifs[0]))
        coords = inputs[:,-embedding.shape[1]:]
        
        with torch.no_grad():
            outputs = model(motif, coords, version='coord-only')
            
        y_test = labels.cpu().numpy()
        y_score = outputs.cpu().numpy()
        y_pred = np.zeros_like(y_score)
        for r_idx, score in enumerate(y_score):
            y_pred[r_idx, np.argmax(score)] = 1
        
        metrics_harvest['Coordinate-Only']['Accuracy'].append(accuracy_score(y_test, y_pred))
        metrics_harvest['Coordinate-Only']['Precision-Macro'].append(precision_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Coordinate-Only']['Precision-Micro'].append(precision_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Coordinate-Only']['Recall-Macro'].append(recall_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Coordinate-Only']['Recall-Micro'].append(recall_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Coordinate-Only']['F1-Macro'].append(f1_score(y_test, y_pred, average='macro', zero_division=0))
        metrics_harvest['Coordinate-Only']['F1-Micro'].append(f1_score(y_test, y_pred, average='micro', zero_division=0))
        metrics_harvest['Coordinate-Only']['AUC-Micro'].append(get_microROC(y_test, y_score))

print("\nAll variant models trained and metrics harvested successfully!")
# Out:
# Harvesting metrics for Combined model...
#
# Training and harvesting Sequence-Only models...
# --- FOLD 1 (Seq-Only) ---
# Epoch 1
# ~ train LOSS: 19.681 | ACC: 0.490
# ~ validate LOSS: 12.985 | ACC: 0.504
#       BEST SO FAR ^ ^ ^
# Epoch 2
# ~ train LOSS: 7.753 | ACC: 0.578
# ~ validate LOSS: 5.652 | ACC: 0.743
#       BEST SO FAR ^ ^ ^
# Epoch 3
# ~ train LOSS: 5.974 | ACC: 0.754
# ~ validate LOSS: 5.326 | ACC: 0.797
#       BEST SO FAR ^ ^ ^
# Epoch 4
# ~ train LOSS: 5.032 | ACC: 0.802
# ~ validate LOSS: 4.572 | ACC: 0.807
#       BEST SO FAR ^ ^ ^
# Epoch 5
# ~ train LOSS: 4.587 | ACC: 0.806
# ~ validate LOSS: 4.368 | ACC: 0.816
#       BEST SO FAR ^ ^ ^
# Epoch 6
# ~ train LOSS: 4.240 | ACC: 0.821
# ~ validate LOSS: 4.011 | ACC: 0.828
#       BEST SO FAR ^ ^ ^
# Epoch 7
# ~ train LOSS: 3.990 | ACC: 0.838
# ~ validate LOSS: 3.980 | ACC: 0.826
#       BEST SO FAR ^ ^ ^
# Epoch 8
# ~ train LOSS: 3.874 | ACC: 0.852
# ~ validate LOSS: 3.878 | ACC: 0.842
#       BEST SO FAR ^ ^ ^
# Epoch 9
# ~ train LOSS: 3.746 | ACC: 0.863
# ~ validate LOSS: 3.844 | ACC: 0.846
#       BEST SO FAR ^ ^ ^
# Epoch 10
# ~ train LOSS: 3.657 | ACC: 0.877
# ~ validate LOSS: 3.960 | ACC: 0.832
# Epoch 11
# ~ train LOSS: 3.576 | ACC: 0.884
# ~ validate LOSS: 3.862 | ACC: 0.842
# Epoch 12
# ~ train LOSS: 3.535 | ACC: 0.889
# ~ validate LOSS: 3.894 | ACC: 0.842
# Epoch 13
# ~ train LOSS: 3.451 | ACC: 0.894
# ~ validate LOSS: 3.899 | ACC: 0.839
# Epoch 14
# ~ train LOSS: 3.277 | ACC: 0.909
#       BEST SO FAR ^ ^ ^
# Epoch 26
# ~ train LOSS: 4.637 | ACC: 0.784
# ~ validate LOSS: 4.492 | ACC: 0.801
#       BEST SO FAR ^ ^ ^
# Epoch 27
# ~ train LOSS: 4.538 | ACC: 0.797
# ~ validate LOSS: 4.450 | ACC: 0.802
#       BEST SO FAR ^ ^ ^
# Epoch 28
# ~ train LOSS: 4.508 | ACC: 0.794
# ~ validate LOSS: 4.380 | ACC: 0.806
#       BEST SO FAR ^ ^ ^
# Epoch 29
# ~ train LOSS: 4.492 | ACC: 0.791
# ~ validate LOSS: 4.361 | ACC: 0.799
#       BEST SO FAR ^ ^ ^
# Epoch 30
# ~ train LOSS: 4.337 | ACC: 0.805
# ~ validate LOSS: 4.281 | ACC: 0.807
#       BEST SO FAR ^ ^ ^
# Epoch 31
# ~ train LOSS: 4.286 | ACC: 0.808
# ~ validate LOSS: 4.158 | ACC: 0.812
#       BEST SO FAR ^ ^ ^
# Epoch 32
# ~ train LOSS: 4.221 | ACC: 0.814
# ~ validate LOSS: 4.132 | ACC: 0.816
#       BEST SO FAR ^ ^ ^
# Epoch 33
# ~ train LOSS: 4.155 | ACC: 0.817
# ~ validate LOSS: 4.044 | ACC: 0.824
#       BEST SO FAR ^ ^ ^
# Epoch 34
# ~ train LOSS: 4.098 | ACC: 0.821
# ~ validate LOSS: 3.987 | ACC: 0.828
#       BEST SO FAR ^ ^ ^
# Epoch 35
# ~ train LOSS: 4.082 | ACC: 0.826
# ~ validate LOSS: 3.979 | ACC: 0.832
#       BEST SO FAR ^ ^ ^
# Epoch 36
# ~ train LOSS: 4.030 | ACC: 0.829
# ~ validate LOSS: 3.939 | ACC: 0.833
#       BEST SO FAR ^ ^ ^
# Epoch 37
# ~ train LOSS: 4.018 | ACC: 0.829
# ~ validate LOSS: 3.920 | ACC: 0.833
#       BEST SO FAR ^ ^ ^
# Epoch 38
# ~ train LOSS: 4.018 | ACC: 0.828
# ~ validate LOSS: 3.875 | ACC: 0.839
#       BEST SO FAR ^ ^ ^
# Epoch 39
# ~ train LOSS: 3.985 | ACC: 0.832
# ~ validate LOSS: 3.938 | ACC: 0.835
# Epoch 40
# ~ train LOSS: 3.939 | ACC: 0.835
# ~ validate LOSS: 3.890 | ACC: 0.839
# --- FOLD 2 (Coord-Only) ---
# Epoch 1
# ~ train LOSS: 19.731 | ACC: 0.483
# ~ validate LOSS: 13.541 | ACC: 0.580
#       BEST SO FAR ^ ^ ^
# Epoch 2
# ~ train LOSS: 8.333 | ACC: 0.580
# ~ validate LOSS: 5.302 | ACC: 0.670
#       BEST SO FAR ^ ^ ^
# Epoch 3
# ~ train LOSS: 6.014 | ACC: 0.665
# ~ validate LOSS: 5.730 | ACC: 0.758
# Epoch 4
# ~ train LOSS: 5.523 | ACC: 0.750
# ~ validate LOSS: 4.794 | ACC: 0.795
#       BEST SO FAR ^ ^ ^
# Epoch 5
# ~ train LOSS: 5.141 | ACC: 0.747
# ~ validate LOSS: 4.957 | ACC: 0.763
# Epoch 6
# ~ train LOSS: 4.981 | ACC: 0.755
# ~ validate LOSS: 4.709 | ACC: 0.793
#       BEST SO FAR ^ ^ ^
# Epoch 7
# ~ train LOSS:
# ~ validate LOSS: 4.678 | ACC: 0.799
#       BEST SO FAR ^ ^ ^
# Epoch 17
# ~ train LOSS: 4.833 | ACC: 0.771
# ~ validate LOSS: 4.660 | ACC: 0.797
#       BEST SO FAR ^ ^ ^
# Epoch 18
# ~ train LOSS: 4.827 | ACC: 0.772
# ~ validate LOSS: 4.630 | ACC: 0.805
#       BEST SO FAR ^ ^ ^
# Epoch 19
# ~ train LOSS: 4.848 | ACC: 0.761
# ~ validate LOSS: 4.681 | ACC: 0.798
# Epoch 20
# ~ train LOSS: 4.822 | ACC: 0.764
# ~ validate LOSS: 4.676 | ACC: 0.798
# Epoch 21
# ~ train LOSS: 4.752 | ACC: 0.782
# ~ validate LOSS: 4.648 | ACC: 0.803
# Epoch 22
# ~ train LOSS: 4.791 | ACC: 0.770
# ~ validate LOSS: 4.635 | ACC: 0.797
# Epoch 23
# ~ train LOSS: 4.768 | ACC: 0.775
# ~ validate LOSS: 4.561 | ACC: 0.807
#       BEST SO FAR ^ ^ ^
# Epoch 24
# ~ train LOSS: 4.756 | ACC: 0.775
# ~ validate LOSS: 4.527 | ACC: 0.813
#       BEST SO FAR ^ ^ ^
# Epoch 25
# ~ train LOSS: 4.697 | ACC: 0.774
# ~ validate LOSS: 4.559 | ACC: 0.796
# Epoch 26
# ~ train LOSS: 4.557 | ACC: 0.793
# ~ validate LOSS: 4.390 | ACC: 0.817
#       BEST SO FAR ^ ^ ^
# Epoch 27
# ~ train LOSS: 4.473 | ACC: 0.803
# ~ validate LOSS: 4.376 | ACC: 0.807
#       BEST SO FAR ^ ^ ^
# Epoch 28
# ~ train LOSS: 4.569 | ACC: 0.781
# ~ validate LOSS: 4.239 | ACC: 0.824
#       BEST SO FAR ^ ^ ^
# Epoch 29
# ~ train LOSS: 4.434 | ACC: 0.796
# ~ validate LOSS: 4.113 | ACC: 0.837
#       BEST SO FAR ^ ^ ^
# Epoch 30
# ~ train LOSS: 4.262 | ACC: 0.814
# ~ validate LOSS: 4.074 | ACC: 0.823
#       BEST SO FAR ^ ^ ^
# Epoch 31
# ~ train LOSS: 4.277 | ACC: 0.800
# ~ validate LOSS: 4.099 | ACC: 0.822
# Epoch 32
# ~ train LOSS: 4.156 | ACC: 0.817
# ~ validate LOSS: 4.050 | ACC: 0.826
#       BEST SO FAR ^ ^ ^
# Epoch 33
# ~ train LOSS: 4.169 | ACC: 0.818
# ~ validate LOSS: 3.842 | ACC: 0.850
#       BEST SO FAR ^ ^ ^
# Epoch 34
# ~ train LOSS: 4.129 | ACC: 0.817
# ~ validate LOSS: 3.930 | ACC: 0.838
# Epoch 35
# ~ train LOSS: 4.179 | ACC: 0.808
# ~ validate LOSS: 3.893 | ACC: 0.843
# Epoch 36
# ~ train LOSS: 3.992 | ACC: 0.830
# ~ validate LOSS: 3.830 | ACC: 0.846
#       BEST SO FAR ^ ^ ^
# Epoch 37
# ~ train LOSS: 4.034 | ACC: 0.828
# ~ validate LOSS: 3.807 | ACC: 0.843
# ~ validate LOSS: 4.781 | ACC: 0.772
# Epoch 23
# ~ train LOSS: 4.763 | ACC: 0.778
# ~ validate LOSS: 4.696 | ACC: 0.796
# Epoch 24
# ~ train LOSS: 4.775 | ACC: 0.776
# ~ validate LOSS: 4.635 | ACC: 0.795
# Epoch 25
# ~ train LOSS: 4.777 | ACC: 0.784
# ~ validate LOSS: 4.659 | ACC: 0.793
# Epoch 26
# ~ train LOSS: 4.694 | ACC: 0.788
# ~ validate LOSS: 4.589 | ACC: 0.797
#       BEST SO FAR ^ ^ ^
# Epoch 27
# ~ train LOSS: 4.661 | ACC: 0.791
# ~ validate LOSS: 4.522 | ACC: 0.804
#       BEST SO FAR ^ ^ ^
# Epoch 28
# ~ train LOSS: 4.636 | ACC: 0.790
# ~ validate LOSS: 4.603 | ACC: 0.786
# Epoch 29
# ~ train LOSS: 4.577 | ACC: 0.796
# ~ validate LOSS: 4.605 | ACC: 0.795
# Epoch 30
# ~ train LOSS: 4.556 | ACC: 0.794
# ~ validate LOSS: 4.609 | ACC: 0.778
# Epoch 31
# ~ train LOSS: 4.495 | ACC: 0.797
# ~ validate LOSS: 4.645 | ACC: 0.775
# Epoch 32
# ~ train LOSS: 4.417 | ACC: 0.804
# ~ validate LOSS: 4.334 | ACC: 0.806
#       BEST SO FAR ^ ^ ^
# Epoch 33
# ~ train LOSS: 4.402 | ACC: 0.804
# ~ validate LOSS: 4.236 | ACC: 0.814
#       BEST SO FAR ^ ^ ^
# Epoch 34
# ~ train LOSS: 4.197 | ACC: 0.822
# ~ validate LOSS: 4.160 | ACC: 0.816
#       BEST SO FAR ^ ^ ^
# Epoch 35
# ~ train LOSS: 4.215 | ACC: 0.817
# ~ validate LOSS: 4.214 | ACC: 0.819
# Epoch 36
# ~ train LOSS: 4.126 | ACC: 0.821
# ~ validate LOSS: 3.885 | ACC: 0.835
#       BEST SO FAR ^ ^ ^
# Epoch 37
# ~ train LOSS: 4.104 | ACC: 0.821
# ~ validate LOSS: 3.889 | ACC: 0.829
# Epoch 38
# ~ train LOSS: 4.079 | ACC: 0.827
# ~ validate LOSS: 3.844 | ACC: 0.841
#       BEST SO FAR ^ ^ ^
# Epoch 39
# ~ train LOSS: 4.000 | ACC: 0.828
# ~ validate LOSS: 3.885 | ACC: 0.835
# Epoch 40
# ~ train LOSS: 4.011 | ACC: 0.831
# ~ validate LOSS: 4.067 | ACC: 0.823
# --- FOLD 5 (Coord-Only) ---
# Epoch 1
# ~ train LOSS: 18.957 | ACC: 0.431
# ~ validate LOSS: 11.243 | ACC: 0.483
#       BEST SO FAR ^ ^ ^
# Epoch 2
# ~ train LOSS: 7.237 | ACC: 0.526
# ~ validate LOSS: 6.137 | ACC: 0.643
#       BEST SO FAR ^ ^ ^
# Epoch 3
# ~ train LOSS: 6.028 | ACC: 0.711
# ~ validate LOSS: 5.330 | ACC: 0.792
#       BEST SO FAR ^ ^ ^
# Epoch 4
# ~ train LOSS: 5.297 | ACC: 0.748
# ~ validate LOSS: 4.083 | ACC: 0.848
# Epoch 28
# ~ train LOSS: 4.135 | ACC: 0.809
# ~ validate LOSS: 3.616 | ACC: 0.856
#       BEST SO FAR ^ ^ ^
# Epoch 29
# ~ train LOSS: 4.137 | ACC: 0.812
# ~ validate LOSS: 3.616 | ACC: 0.866
#       BEST SO FAR ^ ^ ^
# Epoch 30
# ~ train LOSS: 4.013 | ACC: 0.827
# ~ validate LOSS: 3.577 | ACC: 0.892
#       BEST SO FAR ^ ^ ^
# Epoch 31
# ~ train LOSS: 4.050 | ACC: 0.818
# ~ validate LOSS: 3.964 | ACC: 0.857
# Epoch 32
# ~ train LOSS: 3.952 | ACC: 0.832
# ~ validate LOSS: 4.277 | ACC: 0.799
# Epoch 33
# ~ train LOSS: 3.979 | ACC: 0.826
# ~ validate LOSS: 3.682 | ACC: 0.877
# Epoch 34
# ~ train LOSS: 3.968 | ACC: 0.826
# ~ validate LOSS: 3.356 | ACC: 0.891
#       BEST SO FAR ^ ^ ^
# Epoch 35
# ~ train LOSS: 3.895 | ACC: 0.841
# ~ validate LOSS: 3.904 | ACC: 0.861
# Epoch 36
# ~ train LOSS: 3.924 | ACC: 0.835
# ~ validate LOSS: 3.507 | ACC: 0.889
# Epoch 37
# ~ train LOSS: 3.874 | ACC: 0.841
# ~ validate LOSS: 3.564 | ACC: 0.885
# Epoch 38
# ~ train LOSS: 3.917 | ACC: 0.838
# ~ validate LOSS: 3.589 | ACC: 0.888
# Epoch 39
# ~ train LOSS: 3.918 | ACC: 0.836
# ~ validate LOSS: 3.958 | ACC: 0.845
# Epoch 40
# ~ train LOSS: 3.883 | ACC: 0.846
# ~ validate LOSS: 4.091 | ACC: 0.852
#
# All variant models trained and metrics harvested successfully!

# %% [markdown]
# ## Dashboard 1: Model Comparison (Ablation, Radar, CD)
# This dashboard compares the overall predictive performance of our combined Sequence + Structure model against baseline sequence-only and structure-only versions.

# %%
import visualization_engine as ve
import numpy as np

# 1. Generate and display the converged metrics comparison table
ve.generate_metrics_table(metrics_harvest, save_path="FIGS_multiclass/metrics_comparison.csv")

# 2. Model Ablation Bar Plot (subsetting metrics for chart visual clarity)
bar_metrics = {k: {m: v for m, v in metrics_harvest[k].items() if m in ['Accuracy', 'F1-Micro', 'F1-Macro', 'AUC-Micro']} for k in metrics_harvest}
ve.plot_model_comparison(bar_metrics, save_path="FIGS_multiclass/ablation_study.png")

# 3. Performance Radar Chart for top 5 families
ve.plot_performance_radar(y_test, y_score, fams, save_path="FIGS_multiclass/radar_chart.png")

# 4. Critical Difference Diagram (Rank Comparison)
scores_matrix = np.zeros((5, 3))
for f in range(5):
    scores_matrix[f, 0] = metrics_harvest['Combined (Seq+Coord)']['F1-Micro'][f]
    scores_matrix[f, 1] = metrics_harvest['Sequence-Only']['F1-Micro'][f]
    scores_matrix[f, 2] = metrics_harvest['Coordinate-Only']['F1-Micro'][f]

model_names = ['Combined (Seq+Coord)', 'Sequence-Only', 'Coordinate-Only']
ve.plot_critical_difference(scores_matrix, model_names, save_path="FIGS_multiclass/critical_difference.png")
# Out:
# ===============================================================================================
#                       MODEL VARIANT COMPARISON TABLE (CONVERGED ACROSS 5 FOLDS)
# ===============================================================================================
#                              Accuracy  Precision-Macro  Precision-Micro     Recall-Macro     Recall-Micro         F1-Macro         F1-Micro        AUC-Micro
# Model Variant
# Combined (Seq+Coord)  0.3533 ± 0.0280  0.0514 ± 0.0091  0.3533 ± 0.0280  0.0789 ± 0.0066  0.3533 ± 0.0280  0.0545 ± 0.0062  0.3533 ± 0.0280  0.8536 ± 0.0110
# Sequence-Only         0.3582 ± 0.0210  0.0533 ± 0.0062  0.3582 ± 0.0210  0.0822 ± 0.0104  0.3582 ± 0.0210  0.0601 ± 0.0083  0.3582 ± 0.0210  0.8485 ± 0.0101
# Coordinate-Only       0.3600 ± 0.0052  0.0378 ± 0.0013  0.3600 ± 0.0052  0.0792 ± 0.0016  0.3600 ± 0.0052  0.0465 ± 0.0008  0.3600 ± 0.0052  0.8450 ± 0.0138
# ===============================================================================================
#
# Metrics table successfully saved to: FIGS_multiclass/metrics_comparison.csv

# %% [markdown]
# ## Dashboard 2: Biological & Evolutionary Alignment
# This dashboard correlates the model's prediction confusion patterns with standard phylogenetic (BLOSUM62) evolutionary distances between kinase families, showing if model errors align with biological history.

# %%
# 1. Evolutionary Distance vs. Model Confusion Correlation
# famDistMatrix is defined in the dataset loading cells
ve.plot_evolutionary_correlation(y_test, y_score, fams, famDistMatrix, save_path="FIGS_multiclass/evolutionary_alignment.png")

# 2. Grouped Superfamily Confusion Matrix
ve.plot_grouped_confusion_matrix(y_test, y_score, fams, save_path="FIGS_multiclass/grouped_confusion.png")

# %% [markdown]
# ## Dashboard 3: Model Explainability (SHAP Analysis)
# Here we compute SHAP values for our dense PyTorch neural network to see which input features (sequence positions vs. structural 3D Siamese embeddings) are driving predictions.

# %%
# Prepare validation loader representing overall dataset for SHAP
val_loader_shap = get_loader(train_motifs, train_embedding, train_motifxFamMatrix, range(len(train_motifs)), len(train_motifs))

# Instantiate a fresh model and load weights from fold 1
shap_model = Model().to(device)
shap_model.load_state_dict(all_models[0])

# Compute and plot SHAP importance maps
ve.compute_and_plot_shap(
    shap_model, val_loader_shap, device,
    save_path_summary="FIGS_multiclass/shap_summary.png",
    save_path_positional="FIGS_multiclass/shap_positional.png"
)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# ## Dashboard 4: Downstream Clinical Translation
# This final dashboard uses a survival simulator to translate our predicted kinase phosphorylation events (eg. EGFR, AKT1, SRC) into clinical survival estimations (Kaplan-Meier and Cox regression).

# %%
import importlib
import visualization_engine as ve
importlib.reload(ve)
# Out:
# <module 'visualization_engine' from 'c:\\Users\\inaug\\Documents\\GitHub\\SugeethJSA\\Kinase-phosphite-3d_detection-_and_structure_code_and_dataset\\visualization_engine.py'>

# %%
# Kaplan-Meier curves and Cox regression forest plot
ve.plot_survival_dashboard(
    y_score, fams,
    save_path_km="FIGS_multiclass/survival_km.png",
    save_path_cox="FIGS_multiclass/survival_cox.png"
)
